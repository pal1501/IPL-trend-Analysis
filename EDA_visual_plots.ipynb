# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display

# %%
file_path = "playoffs_dataset_cleaned.xlsx"
df = pd.read_excel(file_path)

# %%
# Step 1: Rename Columns for Better Readability
df.columns = ["Year", "Position", "Team", "Matches Played", "Won", "Lost", "Net Run Rate","Points", "For Runs","For Overs", "Against Runs", "Against Overs"]

# %%
print(df.columns)
# Out:
# Index(['Year', 'Position', 'Team', 'Matches Played', 'Won', 'Lost',
#        'Net Run Rate', 'Points', 'For Runs', 'For Overs', 'Against Runs',
#        'Against Overs'],
#       dtype='object')

# %%
# Convert Runs & Overs to Numeric
df["For Runs"] = pd.to_numeric(df["For Runs"], errors='coerce')
df["For Overs"] = pd.to_numeric(df["For Overs"], errors='coerce')
df["Against Runs"] = pd.to_numeric(df["Against Runs"], errors='coerce')
df["Against Overs"] = pd.to_numeric(df["Against Overs"], errors='coerce')

# %%
display(df)
# Out:
#      Year  Position  Team  Matches Played  Won  Lost  Net Run Rate  Points  \
# 0    2008         1    RR              14   11     3         0.632      22
# 1    2008         2  PBKS              14   10     4         0.509      20
# 2    2008         3   CSK              14    8     6        -0.192      16
# 3    2008         4    DD              14    7     6         0.342      15
# 4    2008         5    MI              14    7     7         0.570      14
# ..    ...       ...   ...             ...  ...   ...           ...     ...
# 141  2024         6    DC              14    7     7        -0.377      14
# 142  2024         7   LSG              14    7     7        -0.667      14
# 143  2024         8    GT              14    5     7        -1.063      12
# 144  2024         9  PBKS              14    5     9        -0.353      10
# 145  2024        10    MI              14    4    10        -0.318       8
#
#      For Runs  For Overs  Against Runs  Against Overs
# 0        2245      261.1          2153          270.2
# 1        2352      259.5          2271          265.5
# 2        2241      264.2          2195          253.1
# 3        2001      233.2          2031          246.4
# 4        2080      249.1          2096          269.3
# ..        ...        ...           ...            ...
# 141      2573      267.0          2762          275.5
# 142      2483      277.5          2521          262.3
# 143      2040      238.2          2101          218.2
# 144      2487      274.3          2612          277.3
# 145      2568      268.5          2660          269.3
#
# [146 rows x 12 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# df['Year'].plot(kind='hist', bins=20, title='Year')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# df['Position'].plot(kind='hist', bins=20, title='Position')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# df['Matches Played'].plot(kind='hist', bins=20, title='Matches Played')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# df['Won'].plot(kind='hist', bins=20, title='Won')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# df.plot(kind='scatter', x='Year', y='Position', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# df.plot(kind='scatter', x='Position', y='Matches Played', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# df.plot(kind='scatter', x='Matches Played', y='Won', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# df.plot(kind='scatter', x='Won', y='Lost', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Year']
#   ys = series['Position']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = df.sort_values('Year', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Year')
# _ = plt.ylabel('Position')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Year']
#   ys = series['Matches Played']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = df.sort_values('Year', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Year')
# _ = plt.ylabel('Matches Played')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Year']
#   ys = series['Won']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = df.sort_values('Year', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Year')
# _ = plt.ylabel('Won')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Year']
#   ys = series['Lost']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = df.sort_values('Year', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Year')
# _ = plt.ylabel('Lost')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# df['Year'].plot(kind='line', figsize=(8, 4), title='Year')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# df['Position'].plot(kind='line', figsize=(8, 4), title='Position')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# df['Matches Played'].plot(kind='line', figsize=(8, 4), title='Matches Played')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# df['Won'].plot(kind='line', figsize=(8, 4), title='Won')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
from matplotlib import pyplot as plt
import seaborn as sns
def _plot_series(series, series_name, series_index=0):
  palette = list(sns.palettes.mpl_palette('Dark2'))
  xs = series['Year']
  ys = series['Position']

  plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])

fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
df_sorted = df.sort_values('Year', ascending=True)
_plot_series(df_sorted, '')
sns.despine(fig=fig, ax=ax)
plt.xlabel('Year')
_ = plt.ylabel('Position')

# %%
# prompt: Using dataframe df: total wins vs year

# Group the DataFrame by 'Year' and calculate the sum of 'Won' for each year.
wins_by_year = df.groupby('Year')['Won'].sum()

# Print the result
wins_by_year
# Out:
# Year
# 2008    55
# 2009    54
# 2010    56
# 2011    68
# 2012    70
# 2013    72
# 2014    56
# 2015    53
# 2016    56
# 2017    55
# 2018    56
# 2019    55
# 2020    56
# 2021    56
# 2022    70
# 2023    69
# 2024    67
# Name: Won, dtype: int64

# %%
# @title Position

from matplotlib import pyplot as plt
df['Position'].plot(kind='hist', bins=20, title='Position')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# @title Year

from matplotlib import pyplot as plt
df['Year'].plot(kind='hist', bins=20, title='Year')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# Step 3: Basic Statistics and Overview
print("Dataset Info:")
print(df.info())
print("\nSummary Statistics:")
print(df.describe())
# Out:
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146 entries, 0 to 145
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Year            146 non-null    int64
#  1   Position        146 non-null    int64
#  2   Team            146 non-null    object
#  3   Matches Played  146 non-null    int64
#  4   Won             146 non-null    int64
#  5   Lost            146 non-null    int64
#  6   Net Run Rate    146 non-null    float64
#  7   Points          146 non-null    int64
#  8   For Runs        146 non-null    int64
#  9   For Overs       146 non-null    float64
#  10  Against Runs    146 non-null    int64
#  11  Against Overs   146 non-null    float64
# dtypes: float64(3), int64(8), object(1)
# memory usage: 13.8+ KB
# None
#
# Summary Statistics:
#               Year    Position  Matches Played         Won        Lost  \
# count   146.000000  146.000000      146.000000  146.000000  146.000000
# mean   2016.171233    4.835616       14.246575    7.013699    7.013699
# std       5.005321    2.546200        0.659798    2.027352    2.030751
# min    2008.000000    1.000000       14.000000    2.000000    3.000000
# 25%    2012.000000    3.000000       14.000000    6.000000    5.000000
# 50%    2016.000000    5.000000       14.000000    7.000000    7.000000
# 75%    2021.000000    7.000000       14.000000    8.000000    8.000000
# max    2024.000000   10.000000       16.000000   11.000000   13.000000
#
#        Net Run Rate      Points     For Runs   For Overs  Against Runs  \
# count    146.000000  146.000000   146.000000  146.000000    146.000000
# mean       0.001733   14.246575  2226.965753  269.860274   2226.965753
# std        0.511023    4.030165   200.296450   18.815146    194.428443
# min       -1.436000    4.000000  1687.000000  191.100000   1693.000000
# 25%       -0.349250   12.000000  2118.250000  259.625000   2118.750000
# 50%        0.018000   14.000000  2223.500000  270.350000   2226.500000
# 75%        0.320750   17.000000  2367.250000  276.000000   2350.750000
# max        1.428000   22.000000  2758.000000  319.200000   2762.000000
#
#        Against Overs
# count     146.000000
# mean      269.852055
# std        18.904826
# min       203.200000
# 25%       259.425000
# 50%       271.050000
# 75%       277.000000
# max       315.000000

# %%
# Step 4: Visualizations
plt.figure(figsize=(12, 6))
sns.barplot(x="Year", y="Points", data=df, ci=None)
plt.xticks(rotation=45)
plt.title("Total Points per Year")
plt.show()

plt.figure(figsize=(12, 6))
sns.scatterplot(x="Net Run Rate", y="Points", hue="Team", data=df)
plt.title("Net Run Rate vs. Points")
plt.show()

plt.figure(figsize=(12, 6))
sns.lineplot(x="Year", y="Won", data=df, estimator="sum", ci=None)
plt.title("Total Wins Over the Years")
plt.show()
# Out:
# <ipython-input-19-fe4626eaf9f6>:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x="Year", y="Points", data=df, ci=None)
# <ipython-input-19-fe4626eaf9f6>:14: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(x="Year", y="Won", data=df, estimator="sum", ci=None)

# %% [markdown]
# # New Section
